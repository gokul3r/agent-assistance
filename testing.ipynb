# %%
print("hi")
# Out:
# hi

# %%
import random

# %%
counter=0
first_occurance = 0
for i in range(1,100):
    num = random.randint(1,20)
    if num==1:
        counter+=1
        if first_occurance == 0:
            first_occurance=i
counter, first_occurance
# Out:
# (1, 88)

# %%
random.uniform(0.85, 0.95)
# Out:
# 0.9185748124269911
